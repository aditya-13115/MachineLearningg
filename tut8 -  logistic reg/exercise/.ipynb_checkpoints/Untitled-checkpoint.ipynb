# %% [markdown]
# # Now do some exploratory data analysis to figure out which variables have direct and clear impact on employee retention (i.e. whether they leave the company or continue to work)
# # Plot bar charts showing impact of employee salaries on retention
# # Plot bar charts showing corelation between department and employee retention
# # Now build logistic regression model using variables that were narrowed down in step 1
# # Measure the accuracy of the model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv("HR.csv")
df.head(20)
# Out:
#     satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.38             0.53               2                   157
# 1                 0.80             0.86               5                   262
# 2                 0.11             0.88               7                   272
# 3                 0.72             0.87               5                   223
# 4                 0.37             0.52               2                   159
# 5                 0.41             0.50               2                   153
# 6                 0.10             0.77               6                   247
# 7                 0.92             0.85               5                   259
# 8                 0.89             1.00               5                   224
# 9                 0.42             0.53               2                   142
# 10                0.45             0.54               2                   135
# ...

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   Department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %% [markdown]
# # there is no null value in the data frame.

# %%
plt.scatter(df[['satisfaction_level']],df[['left']],marker='+', alpha=.5 , s=100)
plt.xlabel("Satisfaction label")
plt.ylabel("Left ?")
# Out:
# Text(0, 0.5, 'Left ?')

# %%
plt.hexbin(df['satisfaction_level'], df['left'], gridsize=80, cmap='Blues')
plt.colorbar(label='Count')
plt.xlabel('Satisfaction Level')
plt.ylabel('Left (Yes=1, No=0)')
plt.title('Hexbin Plot of Satisfaction Level vs Left')
plt.show()

# %%
sns.boxplot(x='left', y='satisfaction_level', data=df)
plt.xlabel('Left (Yes=1, No=0)')
plt.ylabel('Satisfaction Level')
plt.title('Boxplot of Satisfaction Level vs Left')
plt.show()

# %%
sns.violinplot(x='left', y='satisfaction_level', data=df)
plt.xlabel('Left (Yes=1, No=0)')
plt.ylabel('Satisfaction Level')
plt.title('Violin Plot of Satisfaction Level vs Left')
plt.show()

# %%
# Using seaborn's strip plot
sns.stripplot(x='left', y='satisfaction_level', data=df, jitter=True, alpha=0.5)
plt.xlabel('Left (Yes=1, No=0)')
plt.ylabel('Satisfaction Level')
plt.title('Strip Plot of Satisfaction Level vs Left')
plt.show()
# Out:
# C:\Users\adity\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\adity\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Combine strip plot with boxplot
sns.boxplot(x='left', y='satisfaction_level', data=df)
sns.stripplot(x='left', y='satisfaction_level', data=df, jitter=True, color='black', alpha=0.5)
plt.xlabel('Left (Yes=1, No=0)')
plt.ylabel('Satisfaction Level')
plt.title('Combined Boxplot and Strip Plot of Satisfaction Level vs Left')
plt.show()
# Out:
# C:\Users\adity\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\adity\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.boxplot(x='number_project', y='left', data=df)
sns.stripplot(x='number_project', y='left', data=df, jitter=True, color='black', alpha=0.5)
plt.xlabel('No. of project')
plt.ylabel('Left')
plt.title('No. of proj vs Left')
plt.show()
# Out:
# C:\Users\adity\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\adity\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.violinplot(x='left', y='number_project', data=df)
plt.xlabel('Left (Yes=1, No=0)')
plt.ylabel('number project')
plt.title('Violin Plot of number project vs Left')
plt.show()

# %%
sns.boxplot(x='left', y='number_project', data=df)
plt.xlabel('Left (Yes=1, No=0)')
plt.ylabel('number project')
plt.title('Boxplot of number project vs Left')
plt.show()

# %%
sns.violinplot(x='left', y='average_montly_hours', data=df)
plt.xlabel('Left (Yes=1, No=0)')
plt.ylabel('average_montly_hours')
plt.title('Violin Plot of average_montly_hours vs Left')
plt.show()

# %%
sns.violinplot(x='left', y='time_spend_company', data=df)
plt.xlabel('Left (Yes=1, No=0)')
plt.ylabel('time_spend_company')
plt.title('Violin Plot of time_spend_company vs Left')
plt.show()

# %%
sns.violinplot(x='left', y='promotion_last_5years', data=df)
plt.xlabel('Left (Yes=1, No=0)')
plt.ylabel('promotion_last_5years')
plt.title('Violin Plot of promotion_last_5years vs Left')
plt.show()

# %%
sns.violinplot(x='left', y='Department', data=df)
plt.xlabel('Left (Yes=1, No=0)')
plt.ylabel('Department')
plt.title('Violin Plot of Department vs Left')
plt.show()

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.groupby('left').mean(numeric_only=True)
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
pd.crosstab(df.salary,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %% [markdown]
# # satisfaction level, time spent in company, promotion in last 5 yr, salary feature selected

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
dummy_sal  = pd.get_dummies(df.salary,dtype=int)

# %%
df = pd.concat([df,dummy_sal],axis=1)

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
X = df[['satisfaction_level','average_montly_hours','Work_accident','promotion_last_5years','high','low','medium']]
X
# Out:
#        satisfaction_level  average_montly_hours  Work_accident  \
# 0                    0.38                   157              0
# 1                    0.80                   262              0
# 2                    0.11                   272              0
# 3                    0.72                   223              0
# 4                    0.37                   159              0
# ...                   ...                   ...            ...
# 14994                0.40                   151              0
# 14995                0.37                   160              0
# 14996                0.37                   143              0
# 14997                0.11                   280              0
# 14998                0.37                   158              0
#
#        promotion_last_5years  high  low  medium
# 0                          0     0    1       0
# 1                          0     0    0       1
# 2                          0     0    0       1
# ...

# %%
y=df[["left"]]
y
# Out:
#        left
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 14994     1
# 14995     1
# 14996     1
# 14997     1
# 14998     1
#
# [14999 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# C:\Users\adity\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.score(X_test,y_test)
# Out:
# 0.7742222222222223
